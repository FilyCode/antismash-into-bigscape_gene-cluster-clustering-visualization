# %%
import os
import Bio
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.SeqFeature import FeatureLocation, SimpleLocation, CompoundLocation, ExactPosition, SeqFeature 

def adjust_and_truncate_location(original_location, offset_int, new_seq_length):
    """
    Manually adjusts a FeatureLocation (Simple or Compound) by an integer offset
    and truncates it to fit within [0, new_seq_length) boundaries.
    Returns None if the location becomes invalid (zero-length or outside bounds) after adjustment.
    """
    if original_location is None or not isinstance(original_location, FeatureLocation):
        return None

    original_start_int = int(original_location.start)
    original_end_int = int(original_location.end)

    if isinstance(original_location, SimpleLocation):
        shifted_start = original_start_int - offset_int
        shifted_end = original_end_int - offset_int
        
        truncated_start = max(0, shifted_start)
        truncated_end = min(new_seq_length, shifted_end)

        if truncated_start >= truncated_end:
            return None # Location is now zero-length or invalid after truncation
        
        return SimpleLocation(truncated_start, truncated_end, original_location.strand)
    
    elif isinstance(original_location, CompoundLocation):
        adjusted_parts = []
        for part in original_location.parts:
            adjusted_part = adjust_and_truncate_location(part, offset_int, new_seq_length)
            if adjusted_part is not None:
                adjusted_parts.append(adjusted_part)
        
        if not adjusted_parts:
             return None # No valid parts remaining after adjustment/truncation
        
        return CompoundLocation(adjusted_parts, original_location.strand, original_location.operator)
    
    else:
        return None # Cannot handle unknown location types, treat as invalid


def split_gbk_by_explicit_region(input_gbk_file, output_base_dir, region_feature_types, 
                                   output_format_extension, min_region_length): 
    """
    Splits a single GenBank file into individual region files (e.g., gene clusters).
    Creates a subdirectory for output from each input file.
    """
    if not os.path.exists(output_base_dir):
        os.makedirs(output_base_dir)

    base_name_without_ext = os.path.splitext(os.path.basename(input_gbk_file))[0]
    specific_output_subdir = output_base_dir
    if not os.path.exists(specific_output_subdir):
        os.makedirs(specific_output_subdir)

    region_candidate_count = 0
    written_files_count = 0

    print(f"\n--- Processing file: {os.path.basename(input_gbk_file)} ---")
    print(f"  Outputting to: {specific_output_subdir}")
    print(f"  Looking for feature types: {', '.join(region_feature_types)}")
    print(f"  Minimum region length: {min_region_length} bp")

    try:
        with open(input_gbk_file, "r") as infile:
            for record in SeqIO.parse(infile, "genbank"):
                print(f"  Processing record: {record.id} (Length: {len(record.seq)} bp)")

                if 'molecule_type' not in record.annotations:
                    record.annotations['molecule_type'] = 'DNA'
                    print(f"    Warning: Added 'molecule_type: DNA' to record {record.id} annotations for extraction.")

                valid_original_features = [f for f in record.features if f.location is not None]

                for feature in valid_original_features: # This 'feature' is the BGC region
                    if feature.type in region_feature_types:
                        region_candidate_count += 1
                        
                        if len(feature.location) < min_region_length:
                            cluster_id_for_print = feature.qualifiers.get('locus_tag', ['unknown'])[0]
                            print(f"    Skipping small feature '{cluster_id_for_print}' (type: {feature.type}, length: {len(feature.location)} bp).")
                            continue

                        cluster_id_base = f"cluster_{region_candidate_count}"
                        if 'region_number' in feature.qualifiers:
                             cluster_id_base = f"region_{feature.qualifiers['region_number'][0]}"
                        elif 'candidate_cluster_number' in feature.qualifiers:
                             cluster_id_base = f"candcluster_{feature.qualifiers['candidate_cluster_number'][0]}"
                        elif 'protocluster_number' in feature.qualifiers:
                             cluster_id_base = f"protocluster_{feature.qualifiers['protocluster_number'][0]}"
                        
                        cluster_id = f"{record.id.replace('.', '_')}_{cluster_id_base}"
                        
                        cluster_note = feature.qualifiers.get('note', feature.qualifiers.get('label', ['unspecified region']))[0]
                        cluster_product = feature.qualifiers.get('product', ['unknown cluster type'])[0]

                        filename_base = "".join(c for c in cluster_id if c.isalnum() or c in ('_', '-'))
                        output_file_path = os.path.join(specific_output_subdir, f"{filename_base}.{output_format_extension}")

                        output_biopython_format = "genbank" if output_format_extension == 'gbk' else "fasta"
                        if output_format_extension not in ['gbk', 'fasta']:
                             print(f"    Warning: Unknown output_format_extension '{output_format_extension}'. Defaulting to 'genbank'.")

                        try:
                            cluster_seq = feature.extract(record.seq)
                            if not cluster_seq:
                                raise ValueError(f"Extracted sequence for {cluster_id} is empty (length 0).")

                            cluster_start_int = int(feature.location.start) # Base for shifting
                            new_cluster_seq_length = len(cluster_seq) # Length of this new segment

                            new_record = SeqRecord(
                                cluster_seq,
                                id=f"{record.id}_{cluster_id_base}",
                                name=cluster_id_base[:16],
                                description=f"{cluster_note} | {cluster_product} | {record.id} region {cluster_start_int}-{int(feature.location.end)}"
                            )
                            if 'molecule_type' in record.annotations:
                                new_record.annotations['molecule_type'] = record.annotations['molecule_type']
                            if 'comment' in record.annotations:
                                new_record.annotations['comment'] = record.annotations['comment']

                            # --- NEW: Create a new 'source' feature matching the new record's length ---
                            new_source_feature_location = FeatureLocation(0, new_cluster_seq_length, 1) # 0-based, forward strand default
                            source_qualifiers = {
                                'mol_type': [record.annotations.get('molecule_type', 'DNA')],
                                'organism': record.annotations.get('organism', ['unknown organism']),
                                'strain': record.annotations.get('strain', ['unknown strain'])
                            }
                            original_source_feature = next((f for f in record.features if f.type == 'source'), None)
                            if original_source_feature and 'db_xref' in original_source_feature.qualifiers:
                                source_qualifiers['db_xref'] = original_source_feature.qualifiers['db_xref']

                            new_record.features.append(
                                SeqFeature(new_source_feature_location, type='source', qualifiers=source_qualifiers)
                            )
                            # --- END NEW: Custom source feature ---

                            # Process features to be added to the new record
                            added_gene_cds_locations = set() # To track (start, end, strand) for genes/CDS already processed
                            
                            for internal_feature in valid_original_features:
                                if internal_feature.type == 'source': # Skip original source, a new one was created
                                    continue

                                internal_start_original = int(internal_feature.location.start)
                                internal_end_original = int(internal_feature.location.end)

                                if (internal_start_original < int(feature.location.end) and internal_end_original > cluster_start_int) and \
                                   internal_feature.type not in region_feature_types: # Do not re-add the main region itself
                                    
                                    feature_to_add_type = internal_feature.type
                                    feature_to_add_location = internal_feature.location
                                    feature_to_add_qualifiers = {**internal_feature.qualifiers}

                                    current_feature_loc_tuple = (internal_feature.location.start, internal_feature.location.end, internal_feature.location.strand)

                                    if internal_feature.type == 'CDS':
                                        # Aggressive CDS filtering
                                        missing_qualifiers = []
                                        if 'translation' not in feature_to_add_qualifiers or not feature_to_add_qualifiers['translation'][0].strip():
                                            missing_qualifiers.append('translation (missing or empty)')
                                        elif len(feature_to_add_qualifiers['translation'][0].strip()) < 5:
                                            missing_qualifiers.append(f"translation (too short: {len(feature_to_add_qualifiers['translation'][0].strip())} aa)")
                                        if 'locus_tag' not in feature_to_add_qualifiers or not feature_to_add_qualifiers['locus_tag'][0].strip():
                                            missing_qualifiers.append('locus_tag (missing or empty)')
                                        if 'product' not in feature_to_add_qualifiers or not feature_to_add_qualifiers['product'][0].strip():
                                            missing_qualifiers.append('product (missing or empty)')
                                        
                                        if missing_qualifiers:
                                            print(f"        Warning: Skipping CDS feature '{feature_to_add_qualifiers.get('locus_tag', ['unknown'])[0]}' (in original record {record.id}, location: {internal_feature.location}) due to missing/malformed essential qualifiers: {', '.join(missing_qualifiers)}.")
                                            continue # Skip this malformed CDS feature
                                        
                                        added_gene_cds_locations.add(current_feature_loc_tuple) # Mark this location as having a valid CDS

                                    elif internal_feature.type == 'gene':
                                        # If a CDS for this gene's location was already added, skip this gene to avoid redundancy
                                        if current_feature_loc_tuple in added_gene_cds_locations:
                                            continue

                                        # --- NEW: Create synthetic CDS for 'gene' features ---
                                        # BiG-SCAPE needs CDS features. If only a 'gene' is present, convert it to a CDS.
                                        
                                        try:
                                            gene_dna_seq = internal_feature.extract(record.seq)
                                            if len(gene_dna_seq) % 3 != 0:
                                                gene_dna_seq = gene_dna_seq[:len(gene_dna_seq) - (len(gene_dna_seq) % 3)]
                                            
                                            translated_aa_seq = str(gene_dna_seq.translate(table=11, cds=False))
                                            if translated_aa_seq.endswith('*'):
                                                translated_aa_seq = translated_aa_seq[:-1]

                                            if not translated_aa_seq.strip() or len(translated_aa_seq.strip()) < 5:
                                                print(f"        Warning: Generated translation for gene '{feature_to_add_qualifiers.get('gene', ['unknown'])[0]}' is too short or empty. Skipping gene.")
                                                continue
                                            
                                            feature_to_add_qualifiers['translation'] = [translated_aa_seq]
                                            feature_to_add_qualifiers['codon_start'] = ['1'] # 1 is standard if no partial start.
                                            print(f"        Info: Generated translation for gene '{feature_to_add_qualifiers.get('gene', ['unknown'])[0]}' (length {len(translated_aa_seq)} aa).")

                                        except Exception as e:
                                            print(f"        Warning: Could not translate gene '{feature_to_add_qualifiers.get('gene', ['unknown'])[0]}' (location: {internal_feature.location}): {e}. Skipping gene.")
                                            continue

                                        if 'locus_tag' not in feature_to_add_qualifiers:
                                            gene_locus_tag = feature_to_add_qualifiers.get('gene', [f"gene_{internal_feature.location.start}"])[0]
                                            feature_to_add_qualifiers['locus_tag'] = [gene_locus_tag]
                                        
                                        feature_to_add_type = 'CDS' # Change type to CDS
                                        added_gene_cds_locations.add(current_feature_loc_tuple) # Mark this location as having a valid CDS

                                    else: # Skip other non-CDS/non-gene internal features
                                        continue
                                    # --- END NEW: Synthetic CDS for 'gene' features ---
                                    
                                    # If a feature (either original CDS or synthetic CDS) is ready to be added
                                    adjusted_location = adjust_and_truncate_location(feature_to_add_location, cluster_start_int, new_cluster_seq_length)
                                    
                                    if adjusted_location is None: # Location became invalid after adjustment/truncation
                                        print(f"        Warning: Skipping malformed internal feature '{feature_to_add_type}' (original location: {feature_to_add_location}) as its location became invalid after adjustment/truncation.")
                                        continue

                                    adjusted_feature = internal_feature.__class__( # Use original class type to maintain consistency
                                        adjusted_location,
                                        type=feature_to_add_type, # Use the potentially modified type (CDS for synthetic)
                                        qualifiers=feature_to_add_qualifiers # Use the potentially modified qualifiers
                                    )
                                    new_record.features.append(adjusted_feature)
                            
                            # Add the encompassing region feature itself, RETAINING its original type
                            adjusted_region_location = adjust_and_truncate_location(feature.location, cluster_start_int, new_cluster_seq_length)
                            
                            if adjusted_region_location is None: # Critical check for the main region feature
                                raise ValueError(f"Region feature '{cluster_id}' location became invalid after adjustment/truncation. Cannot create file.")

                            feature_qualifiers_for_adjusted_feature = {**feature.qualifiers}
                            if feature.type == 'region' and 'locus_tag' not in feature_qualifiers_for_adjusted_feature:
                                feature_qualifiers_for_adjusted_feature['locus_tag'] = [cluster_id_base]

                            region_feature_adjusted = feature.__class__(
                                adjusted_region_location,
                                type=feature.type,
                                qualifiers=feature_qualifiers_for_adjusted_feature
                            )
                            new_record.features.insert(0, region_feature_adjusted) # Insert first to be prominent

                            with open(output_file_path, "w") as outfile:
                                SeqIO.write(new_record, outfile, output_biopython_format)
                            print(f"    Wrote {output_biopython_format.capitalize()} for cluster '{cluster_id_base}' (type: {feature.type}) to {os.path.basename(output_file_path)}")
                            written_files_count += 1

                        except ValueError as e:
                            print(f"    Could not write file for region '{cluster_id}' (location {feature.location}): {e}")
                            continue

    except FileNotFoundError:
        print(f"Error: Input file '{input_gbk_file}' not found.")
    except Exception as e:
        print(f"An unexpected error occurred while processing '{input_gbk_file}': {e}")
    
    print(f"  Finished processing {os.path.basename(input_gbk_file)}. Identified {region_candidate_count} features matching specified types. Successfully wrote {written_files_count} files after filtering by length.")


if __name__ == "__main__":
    current_directory = os.getcwd()
    output_base_dir = "split_gbk_regions_output"

    if not os.path.exists(output_base_dir):
        os.makedirs(output_base_dir)

    gbk_files_found = []
    for filename in os.listdir(current_directory):
        if filename.endswith(".gbk"):
            gbk_files_found.append(os.path.join(current_directory, filename))

    if not gbk_files_found:
        print(f"No .gbk files found in the current directory: {current_directory}")
    else:
        print(f"Found {len(gbk_files_found)} .gbk file(s) in '{current_directory}'.")
        print(f"All extracted regions will be placed in subdirectories within '{output_base_dir}'.")
        print("-" * 50)

        for gbk_file_path in gbk_files_found:
            split_gbk_by_explicit_region(
                gbk_file_path,
                output_base_dir,
                region_feature_types=['region'],
                output_format_extension='gbk',
                min_region_length=1000
            )
            print("-" * 50)

        print(f"\nAll specified GenBank files processed. Output can be found in '{output_base_dir}'.")
# Out:
# Found 11 .gbk file(s) in 'c:\Users\poker\Downloads'.
# All extracted regions will be placed in subdirectories within 'split_gbk_regions_output'.
# --------------------------------------------------
#
# --- Processing file: GCF_000154965.1.gbk ---
#   Outputting to: split_gbk_regions_output
#   Looking for feature types: region
#   Minimum region length: 1000 bp
#   Processing record: NZ_CM000951.1 (Length: 9313494 bp)
#         Info: Generated translation for gene 'unknown' (length 475 aa).
#         Info: Generated translation for gene 'unknown' (length 522 aa).
#         Info: Generated translation for gene 'unknown' (length 62 aa).
#         Info: Generated translation for gene 'unknown' (length 407 aa).
#         Info: Generated translation for gene 'unknown' (length 247 aa).
#         Info: Generated translation for gene 'unknown' (length 179 aa).
#         Info: Generated translation for gene 'unknown' (length 424 aa).
#         Info: Generated translation for gene 'unknown' (length 200 aa).
#         Info: Generated translation for gene 'unknown' (length 53 aa).
#         Info: Generated translation for gene 'unknown' (length 262 aa).
#         Info: Generated translation for gene 'unknown' (length 373 aa).
#         Info: Generated translation for gene 'unknown' (length 511 aa).
#         Info: Generated translation for gene 'unknown' (length 216 aa).
#         Info: Generated translation for gene 'unknown' (length 47 aa).
#         Info: Generated translation for gene 'unknown' (length 114 aa).
#         Info: Generated translation for gene 'unknown' (length 720 aa).
#         Info: Generated translation for gene 'unknown' (length 394 aa).
#         Info: Generated translation for gene 'unknown' (length 126 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 766 aa).
#         Info: Generated translation for gene 'unknown' (length 130 aa).
#         Info: Generated translation for gene 'unknown' (length 261 aa).
#         Info: Generated translation for gene 'unknown' (length 292 aa).
#         Info: Generated translation for gene 'unknown' (length 299 aa).
#         Info: Generated translation for gene 'unknown' (length 43 aa).
#         Info: Generated translation for gene 'unknown' (length 308 aa).
#         Info: Generated translation for gene 'unknown' (length 97 aa).
#         Info: Generated translation for gene 'unknown' (length 205 aa).
#         Info: Generated translation for gene 'unknown' (length 72 aa).
#         Info: Generated translation for gene 'unknown' (length 35 aa).
#         Info: Generated translation for gene 'unknown' (length 281 aa).
#         Info: Generated translation for gene 'unknown' (length 59 aa).
#         Info: Generated translation for gene 'unknown' (length 118 aa).
#         Info: Generated translation for gene 'unknown' (length 170 aa).
#         Info: Generated translation for gene 'unknown' (length 169 aa).
#         Info: Generated translation for gene 'ligA' (length 694 aa).
#     Wrote Genbank for cluster 'region_1' (type: region) to NZ_CM000951_1_region_1.gbk
#         Info: Generated translation for gene 'unknown' (length 226 aa).
#         Info: Generated translation for gene 'unknown' (length 250 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 255 aa).
#         Info: Generated translation for gene 'unknown' (length 196 aa).
#         Info: Generated translation for gene 'bcpA' (length 296 aa).
#         Info: Generated translation for gene 'unknown' (length 246 aa).
#         Info: Generated translation for gene 'unknown' (length 428 aa).
#         Info: Generated translation for gene 'unknown' (length 383 aa).
#         Info: Generated translation for gene 'unknown' (length 412 aa).
#         Info: Generated translation for gene 'unknown' (length 468 aa).
#         Info: Generated translation for gene 'unknown' (length 284 aa).
#         Info: Generated translation for gene 'unknown' (length 356 aa).
#         Info: Generated translation for gene 'unknown' (length 126 aa).
#         Info: Generated translation for gene 'aepX' (length 297 aa).
#         Info: Generated translation for gene 'unknown' (length 476 aa).
#         Info: Generated translation for gene 'unknown' (length 556 aa).
#         Info: Generated translation for gene 'unknown' (length 82 aa).
#         Info: Generated translation for gene 'unknown' (length 223 aa).
#         Info: Generated translation for gene 'unknown' (length 328 aa).
#         Info: Generated translation for gene 'unknown' (length 261 aa).
#         Info: Generated translation for gene 'unknown' (length 330 aa).
#         Info: Generated translation for gene 'unknown' (length 335 aa).
#         Info: Generated translation for gene 'unknown' (length 919 aa).
#         Info: Generated translation for gene 'unknown' (length 242 aa).
#         Info: Generated translation for gene 'unknown' (length 548 aa).
#         Info: Generated translation for gene 'unknown' (length 328 aa).
#         Info: Generated translation for gene 'unknown' (length 231 aa).
#         Info: Generated translation for gene 'unknown' (length 146 aa).
#         Info: Generated translation for gene 'unknown' (length 122 aa).
#         Info: Generated translation for gene 'unknown' (length 189 aa).
#         Info: Generated translation for gene 'unknown' (length 124 aa).
#         Info: Generated translation for gene 'unknown' (length 166 aa).
#         Info: Generated translation for gene 'unknown' (length 282 aa).
#         Info: Generated translation for gene 'unknown' (length 141 aa).
#         Info: Generated translation for gene 'unknown' (length 203 aa).
#         Info: Generated translation for gene 'unknown' (length 352 aa).
#         Info: Generated translation for gene 'unknown' (length 188 aa).
#         Info: Generated translation for gene 'unknown' (length 207 aa).
#         Info: Generated translation for gene 'unknown' (length 191 aa).
#         Info: Generated translation for gene 'unknown' (length 181 aa).
#         Info: Generated translation for gene 'unknown' (length 315 aa).
#         Info: Generated translation for gene 'unknown' (length 148 aa).
#         Info: Generated translation for gene 'unknown' (length 145 aa).
#         Info: Generated translation for gene 'unknown' (length 86 aa).
#         Info: Generated translation for gene 'unknown' (length 587 aa).
#         Info: Generated translation for gene 'unknown' (length 527 aa).
#     Wrote Genbank for cluster 'region_2' (type: region) to NZ_CM000951_1_region_2.gbk
#         Info: Generated translation for gene 'unknown' (length 1120 aa).
#         Info: Generated translation for gene 'unknown' (length 386 aa).
#         Info: Generated translation for gene 'unknown' (length 350 aa).
#         Info: Generated translation for gene 'unknown' (length 92 aa).
#         Info: Generated translation for gene 'unknown' (length 137 aa).
#         Info: Generated translation for gene 'unknown' (length 136 aa).
#         Info: Generated translation for gene 'unknown' (length 523 aa).
#         Info: Generated translation for gene 'unknown' (length 197 aa).
#         Info: Generated translation for gene 'unknown' (length 60 aa).
#         Info: Generated translation for gene 'unknown' (length 47 aa).
#         Info: Generated translation for gene 'unknown' (length 201 aa).
#         Info: Generated translation for gene 'unknown' (length 310 aa).
#         Info: Generated translation for gene 'unknown' (length 201 aa).
#         Info: Generated translation for gene 'unknown' (length 369 aa).
#         Info: Generated translation for gene 'unknown' (length 316 aa).
#         Info: Generated translation for gene 'unknown' (length 316 aa).
#         Info: Generated translation for gene 'unknown' (length 439 aa).
#         Info: Generated translation for gene 'unknown' (length 491 aa).
#         Info: Generated translation for gene 'unknown' (length 341 aa).
#         Info: Generated translation for gene 'unknown' (length 437 aa).
#         Info: Generated translation for gene 'unknown' (length 250 aa).
#         Info: Generated translation for gene 'unknown' (length 76 aa).
#         Info: Generated translation for gene 'unknown' (length 405 aa).
#         Info: Generated translation for gene 'unknown' (length 366 aa).
#         Info: Generated translation for gene 'unknown' (length 464 aa).
#         Info: Generated translation for gene 'unknown' (length 203 aa).
#         Info: Generated translation for gene 'unknown' (length 300 aa).
#         Info: Generated translation for gene 'unknown' (length 533 aa).
#         Info: Generated translation for gene 'unknown' (length 71 aa).
#         Info: Generated translation for gene 'unknown' (length 236 aa).
#         Info: Generated translation for gene 'unknown' (length 274 aa).
#         Info: Generated translation for gene 'unknown' (length 871 aa).
#         Info: Generated translation for gene 'unknown' (length 125 aa).
#         Info: Generated translation for gene 'unknown' (length 102 aa).
#         Info: Generated translation for gene 'unknown' (length 340 aa).
#         Info: Generated translation for gene 'unknown' (length 415 aa).
#         Info: Generated translation for gene 'unknown' (length 155 aa).
#         Info: Generated translation for gene 'unknown' (length 118 aa).
#         Info: Generated translation for gene 'unknown' (length 147 aa).
#         Info: Generated translation for gene 'unknown' (length 103 aa).
#         Info: Generated translation for gene 'unknown' (length 356 aa).
#         Info: Generated translation for gene 'unknown' (length 174 aa).
#         Info: Generated translation for gene 'unknown' (length 165 aa).
#         Info: Generated translation for gene 'unknown' (length 263 aa).
#         Info: Generated translation for gene 'unknown' (length 248 aa).
#         Info: Generated translation for gene 'unknown' (length 110 aa).
#         Info: Generated translation for gene 'unknown' (length 45 aa).
#         Info: Generated translation for gene 'unknown' (length 171 aa).
#         Info: Generated translation for gene 'unknown' (length 191 aa).
#         Info: Generated translation for gene 'unknown' (length 345 aa).
#         Info: Generated translation for gene 'unknown' (length 474 aa).
#         Info: Generated translation for gene 'unknown' (length 755 aa).
#         Info: Generated translation for gene 'unknown' (length 178 aa).
#         Info: Generated translation for gene 'unknown' (length 711 aa).
#     Wrote Genbank for cluster 'region_3' (type: region) to NZ_CM000951_1_region_3.gbk
#         Info: Generated translation for gene 'unknown' (length 606 aa).
#         Info: Generated translation for gene 'unknown' (length 395 aa).
#         Info: Generated translation for gene 'unknown' (length 167 aa).
#         Info: Generated translation for gene 'ppsA' (length 865 aa).
#         Info: Generated translation for gene 'unknown' (length 112 aa).
#         Info: Generated translation for gene 'unknown' (length 429 aa).
#         Info: Generated translation for gene 'unknown' (length 266 aa).
#         Info: Generated translation for gene 'unknown' (length 193 aa).
#         Info: Generated translation for gene 'unknown' (length 243 aa).
#         Info: Generated translation for gene 'unknown' (length 397 aa).
#         Info: Generated translation for gene 'unknown' (length 202 aa).
#         Info: Generated translation for gene 'unknown' (length 511 aa).
#         Info: Generated translation for gene 'unknown' (length 335 aa).
#         Info: Generated translation for gene 'unknown' (length 338 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 85 aa).
#         Info: Generated translation for gene 'unknown' (length 49 aa).
#         Info: Generated translation for gene 'unknown' (length 73 aa).
#         Info: Generated translation for gene 'unknown' (length 105 aa).
#         Info: Generated translation for gene 'unknown' (length 103 aa).
#         Info: Generated translation for gene 'unknown' (length 378 aa).
#         Info: Generated translation for gene 'unknown' (length 443 aa).
#         Info: Generated translation for gene 'unknown' (length 297 aa).
#         Info: Generated translation for gene 'unknown' (length 250 aa).
#         Info: Generated translation for gene 'unknown' (length 99 aa).
#     Wrote Genbank for cluster 'region_4' (type: region) to NZ_CM000951_1_region_4.gbk
#         Info: Generated translation for gene 'unknown' (length 250 aa).
#         Info: Generated translation for gene 'unknown' (length 466 aa).
#         Info: Generated translation for gene 'unknown' (length 132 aa).
#         Info: Generated translation for gene 'unknown' (length 291 aa).
#         Info: Generated translation for gene 'unknown' (length 83 aa).
#         Info: Generated translation for gene 'unknown' (length 268 aa).
#         Info: Generated translation for gene 'unknown' (length 40 aa).
#         Info: Generated translation for gene 'unknown' (length 246 aa).
#         Info: Generated translation for gene 'unknown' (length 264 aa).
#         Info: Generated translation for gene 'unknown' (length 303 aa).
#         Info: Generated translation for gene 'unknown' (length 191 aa).
#         Info: Generated translation for gene 'unknown' (length 494 aa).
#         Info: Generated translation for gene 'unknown' (length 101 aa).
#         Info: Generated translation for gene 'unknown' (length 373 aa).
#         Info: Generated translation for gene 'unknown' (length 442 aa).
#         Info: Generated translation for gene 'unknown' (length 222 aa).
#         Info: Generated translation for gene 'unknown' (length 530 aa).
#         Info: Generated translation for gene 'unknown' (length 144 aa).
#         Info: Generated translation for gene 'unknown' (length 276 aa).
#         Info: Generated translation for gene 'unknown' (length 48 aa).
#         Warning: Skipping CDS feature 'SSEG_RS46525' (in original record NZ_CM000951.1, location: [<628972:>629117](-)) due to missing/malformed essential qualifiers: translation (too short: 3 aa).
#         Info: Generated translation for gene 'unknown' (length 218 aa).
#         Info: Generated translation for gene 'unknown' (length 206 aa).
#         Info: Generated translation for gene 'unknown' (length 516 aa).
#         Info: Generated translation for gene 'unknown' (length 332 aa).
#         Info: Generated translation for gene 'unknown' (length 307 aa).
#         Info: Generated translation for gene 'unknown' (length 410 aa).
#         Info: Generated translation for gene 'unknown' (length 570 aa).
#         Info: Generated translation for gene 'unknown' (length 79 aa).
#         Info: Generated translation for gene 'unknown' (length 113 aa).
#         Info: Generated translation for gene 'unknown' (length 389 aa).
#         Info: Generated translation for gene 'unknown' (length 275 aa).
#         Info: Generated translation for gene 'unknown' (length 488 aa).
#         Info: Generated translation for gene 'unknown' (length 230 aa).
#         Info: Generated translation for gene 'unknown' (length 243 aa).
#         Info: Generated translation for gene 'unknown' (length 228 aa).
#         Info: Generated translation for gene 'unknown' (length 150 aa).
#         Info: Generated translation for gene 'unknown' (length 210 aa).
#         Info: Generated translation for gene 'unknown' (length 451 aa).
#         Info: Generated translation for gene 'unknown' (length 176 aa).
#         Info: Generated translation for gene 'unknown' (length 294 aa).
#         Info: Generated translation for gene 'unknown' (length 193 aa).
#         Info: Generated translation for gene 'unknown' (length 72 aa).
#         Info: Generated translation for gene 'unknown' (length 247 aa).
#     Wrote Genbank for cluster 'region_5' (type: region) to NZ_CM000951_1_region_5.gbk
#         Info: Generated translation for gene 'unknown' (length 565 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 492 aa).
#         Info: Generated translation for gene 'unknown' (length 405 aa).
#         Info: Generated translation for gene 'unknown' (length 114 aa).
#         Info: Generated translation for gene 'unknown' (length 274 aa).
#         Info: Generated translation for gene 'unknown' (length 150 aa).
#         Info: Generated translation for gene 'unknown' (length 232 aa).
#         Info: Generated translation for gene 'unknown' (length 193 aa).
#         Info: Generated translation for gene 'unknown' (length 147 aa).
#         Info: Generated translation for gene 'unknown' (length 266 aa).
#         Info: Generated translation for gene 'unknown' (length 302 aa).
#     Wrote Genbank for cluster 'region_6' (type: region) to NZ_CM000951_1_region_6.gbk
#         Info: Generated translation for gene 'unknown' (length 491 aa).
#         Info: Generated translation for gene 'unknown' (length 171 aa).
#         Info: Generated translation for gene 'unknown' (length 360 aa).
#         Info: Generated translation for gene 'unknown' (length 130 aa).
#         Info: Generated translation for gene 'unknown' (length 236 aa).
#         Info: Generated translation for gene 'unknown' (length 148 aa).
#         Info: Generated translation for gene 'unknown' (length 301 aa).
#         Info: Generated translation for gene 'unknown' (length 592 aa).
#         Info: Generated translation for gene 'unknown' (length 264 aa).
#         Info: Generated translation for gene 'unknown' (length 140 aa).
#         Info: Generated translation for gene 'unknown' (length 197 aa).
#         Info: Generated translation for gene 'unknown' (length 27 aa).
#         Info: Generated translation for gene 'unknown' (length 246 aa).
#         Info: Generated translation for gene 'unknown' (length 440 aa).
#         Info: Generated translation for gene 'unknown' (length 387 aa).
#         Info: Generated translation for gene 'unknown' (length 118 aa).
#         Info: Generated translation for gene 'unknown' (length 348 aa).
#         Info: Generated translation for gene 'unknown' (length 271 aa).
#         Info: Generated translation for gene 'unknown' (length 381 aa).
#         Info: Generated translation for gene 'unknown' (length 67 aa).
#         Info: Generated translation for gene 'unknown' (length 405 aa).
#         Info: Generated translation for gene 'sfnG' (length 369 aa).
#     Wrote Genbank for cluster 'region_7' (type: region) to NZ_CM000951_1_region_7.gbk
#         Info: Generated translation for gene 'unknown' (length 312 aa).
#         Info: Generated translation for gene 'mshC' (length 409 aa).
#         Info: Generated translation for gene 'unknown' (length 270 aa).
#         Info: Generated translation for gene 'unknown' (length 196 aa).
#         Info: Generated translation for gene 'unknown' (length 228 aa).
#         Info: Generated translation for gene 'corA' (length 331 aa).
#         Info: Generated translation for gene 'unknown' (length 262 aa).
#         Info: Generated translation for gene 'unknown' (length 351 aa).
#         Info: Generated translation for gene 'unknown' (length 327 aa).
#         Info: Generated translation for gene 'unknown' (length 592 aa).
#         Info: Generated translation for gene 'unknown' (length 226 aa).
#         Info: Generated translation for gene 'unknown' (length 62 aa).
#         Info: Generated translation for gene 'unknown' (length 77 aa).
#         Info: Generated translation for gene 'unknown' (length 441 aa).
#         Info: Generated translation for gene 'unknown' (length 29 aa).
#         Info: Generated translation for gene 'unknown' (length 1288 aa).
#         Info: Generated translation for gene 'unknown' (length 458 aa).
#         Info: Generated translation for gene 'unknown' (length 130 aa).
#         Info: Generated translation for gene 'unknown' (length 233 aa).
#         Info: Generated translation for gene 'unknown' (length 168 aa).
#         Info: Generated translation for gene 'unknown' (length 465 aa).
#         Info: Generated translation for gene 'unknown' (length 199 aa).
#         Info: Generated translation for gene 'unknown' (length 206 aa).
#         Info: Generated translation for gene 'unknown' (length 242 aa).
#         Info: Generated translation for gene 'unknown' (length 510 aa).
#         Info: Generated translation for gene 'unknown' (length 316 aa).
#         Info: Generated translation for gene 'unknown' (length 297 aa).
#         Info: Generated translation for gene 'unknown' (length 171 aa).
#         Info: Generated translation for gene 'unknown' (length 371 aa).
#         Info: Generated translation for gene 'unknown' (length 355 aa).
#         Info: Generated translation for gene 'unknown' (length 130 aa).
#     Wrote Genbank for cluster 'region_8' (type: region) to NZ_CM000951_1_region_8.gbk
#         Info: Generated translation for gene 'unknown' (length 277 aa).
#         Info: Generated translation for gene 'unknown' (length 283 aa).
#         Info: Generated translation for gene 'unknown' (length 366 aa).
#         Info: Generated translation for gene 'ectA' (length 175 aa).
#         Info: Generated translation for gene 'ectB' (length 423 aa).
#         Info: Generated translation for gene 'unknown' (length 134 aa).
#         Info: Generated translation for gene 'thpD' (length 298 aa).
#         Info: Generated translation for gene 'unknown' (length 350 aa).
#         Info: Generated translation for gene 'unknown' (length 241 aa).
#         Info: Generated translation for gene 'unknown' (length 202 aa).
#         Info: Generated translation for gene 'unknown' (length 488 aa).
#     Wrote Genbank for cluster 'region_9' (type: region) to NZ_CM000951_1_region_9.gbk
#         Info: Generated translation for gene 'unknown' (length 728 aa).
#         Info: Generated translation for gene 'unknown' (length 292 aa).
#         Info: Generated translation for gene 'unknown' (length 127 aa).
#         Info: Generated translation for gene 'unknown' (length 319 aa).
#         Info: Generated translation for gene 'unknown' (length 99 aa).
#         Info: Generated translation for gene 'unknown' (length 288 aa).
#         Info: Generated translation for gene 'unknown' (length 159 aa).
#         Info: Generated translation for gene 'unknown' (length 170 aa).
#         Info: Generated translation for gene 'unknown' (length 190 aa).
#         Info: Generated translation for gene 'unknown' (length 166 aa).
#         Info: Generated translation for gene 'unknown' (length 93 aa).
#         Info: Generated translation for gene 'unknown' (length 170 aa).
#         Info: Generated translation for gene 'unknown' (length 79 aa).
#         Info: Generated translation for gene 'unknown' (length 369 aa).
#         Info: Generated translation for gene 'unknown' (length 346 aa).
#     Wrote Genbank for cluster 'region_10' (type: region) to NZ_CM000951_1_region_10.gbk
#         Info: Generated translation for gene 'unknown' (length 262 aa).
#         Info: Generated translation for gene 'unknown' (length 288 aa).
#         Info: Generated translation for gene 'unknown' (length 385 aa).
#         Info: Generated translation for gene 'unknown' (length 197 aa).
#         Info: Generated translation for gene 'unknown' (length 538 aa).
#         Info: Generated translation for gene 'unknown' (length 637 aa).
#         Info: Generated translation for gene 'unknown' (length 306 aa).
#         Info: Generated translation for gene 'unknown' (length 386 aa).
#         Info: Generated translation for gene 'unknown' (length 348 aa).
#         Info: Generated translation for gene 'unknown' (length 269 aa).
#         Info: Generated translation for gene 'desA' (length 480 aa).
#         Info: Generated translation for gene 'unknown' (length 425 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 590 aa).
#         Info: Generated translation for gene 'unknown' (length 263 aa).
#         Info: Generated translation for gene 'unknown' (length 215 aa).
#         Info: Generated translation for gene 'unknown' (length 297 aa).
#         Info: Generated translation for gene 'unknown' (length 520 aa).
#         Info: Generated translation for gene 'unknown' (length 85 aa).
#         Info: Generated translation for gene 'glmS' (length 605 aa).
#         Info: Generated translation for gene 'unknown' (length 175 aa).
#         Info: Generated translation for gene 'unknown' (length 101 aa).
#         Info: Generated translation for gene 'unknown' (length 415 aa).
#         Info: Generated translation for gene 'orn' (length 200 aa).
#         Info: Generated translation for gene 'unknown' (length 25 aa).
#         Info: Generated translation for gene 'unknown' (length 291 aa).
#         Info: Generated translation for gene 'unknown' (length 298 aa).
#         Info: Generated translation for gene 'unknown' (length 259 aa).
#         Info: Generated translation for gene 'unknown' (length 351 aa).
#     Wrote Genbank for cluster 'region_11' (type: region) to NZ_CM000951_1_region_11.gbk
#         Info: Generated translation for gene 'unknown' (length 351 aa).
#         Info: Generated translation for gene 'pknB' (length 663 aa).
#         Info: Generated translation for gene 'unknown' (length 490 aa).
#         Info: Generated translation for gene 'unknown' (length 484 aa).
#         Info: Generated translation for gene 'unknown' (length 521 aa).
#         Info: Generated translation for gene 'unknown' (length 170 aa).
#         Info: Generated translation for gene 'unknown' (length 298 aa).
#         Info: Generated translation for gene 'unknown' (length 29 aa).
#         Info: Generated translation for gene 'unknown' (length 29 aa).
#         Info: Generated translation for gene 'unknown' (length 246 aa).
#         Info: Generated translation for gene 'unknown' (length 182 aa).
#         Info: Generated translation for gene 'unknown' (length 310 aa).
#         Info: Generated translation for gene 'unknown' (length 967 aa).
#         Info: Generated translation for gene 'unknown' (length 59 aa).
#         Info: Generated translation for gene 'unknown' (length 237 aa).
#         Info: Generated translation for gene 'unknown' (length 357 aa).
#         Info: Generated translation for gene 'unknown' (length 384 aa).
#         Info: Generated translation for gene 'unknown' (length 231 aa).
#         Info: Generated translation for gene 'unknown' (length 1138 aa).
#         Info: Generated translation for gene 'unknown' (length 374 aa).
#         Info: Generated translation for gene 'lysX' (length 292 aa).
#         Info: Generated translation for gene 'unknown' (length 258 aa).
#         Info: Generated translation for gene 'unknown' (length 195 aa).
#         Info: Generated translation for gene 'unknown' (length 350 aa).
#         Info: Generated translation for gene 'unknown' (length 431 aa).
#         Info: Generated translation for gene 'unknown' (length 280 aa).
#         Info: Generated translation for gene 'unknown' (length 322 aa).
#         Info: Generated translation for gene 'unknown' (length 59 aa).
#         Info: Generated translation for gene 'unknown' (length 243 aa).
#         Info: Generated translation for gene 'unknown' (length 576 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 254 aa).
#         Info: Generated translation for gene 'unknown' (length 282 aa).
#         Info: Generated translation for gene 'unknown' (length 309 aa).
#         Info: Generated translation for gene 'unknown' (length 418 aa).
#         Info: Generated translation for gene 'unknown' (length 304 aa).
#         Info: Generated translation for gene 'unknown' (length 495 aa).
#         Info: Generated translation for gene 'unknown' (length 451 aa).
#         Info: Generated translation for gene 'unknown' (length 291 aa).
#         Info: Generated translation for gene 'unknown' (length 274 aa).
#     Wrote Genbank for cluster 'region_12' (type: region) to NZ_CM000951_1_region_12.gbk
#         Info: Generated translation for gene 'unknown' (length 446 aa).
#         Info: Generated translation for gene 'unknown' (length 244 aa).
#         Info: Generated translation for gene 'unknown' (length 111 aa).
#         Info: Generated translation for gene 'unknown' (length 126 aa).
#         Info: Generated translation for gene 'unknown' (length 430 aa).
#         Info: Generated translation for gene 'unknown' (length 70 aa).
#         Info: Generated translation for gene 'unknown' (length 107 aa).
#         Info: Generated translation for gene 'unknown' (length 428 aa).
#         Info: Generated translation for gene 'unknown' (length 234 aa).
#         Info: Generated translation for gene 'unknown' (length 209 aa).
#         Info: Generated translation for gene 'unknown' (length 328 aa).
#         Info: Generated translation for gene 'unknown' (length 344 aa).
#         Info: Generated translation for gene 'unknown' (length 443 aa).
#         Info: Generated translation for gene 'unknown' (length 203 aa).
#         Info: Generated translation for gene 'unknown' (length 348 aa).
#         Info: Generated translation for gene 'unknown' (length 200 aa).
#         Info: Generated translation for gene 'unknown' (length 274 aa).
#         Info: Generated translation for gene 'unknown' (length 144 aa).
#         Info: Generated translation for gene 'unknown' (length 75 aa).
#         Info: Generated translation for gene 'unknown' (length 148 aa).
#         Info: Generated translation for gene 'unknown' (length 231 aa).
#         Info: Generated translation for gene 'amaP' (length 197 aa).
#         Info: Generated translation for gene 'unknown' (length 56 aa).
#         Info: Generated translation for gene 'unknown' (length 289 aa).
#         Info: Generated translation for gene 'unknown' (length 355 aa).
#         Info: Generated translation for gene 'unknown' (length 182 aa).
#         Info: Generated translation for gene 'unknown' (length 337 aa).
#         Info: Generated translation for gene 'unknown' (length 442 aa).
#         Info: Generated translation for gene 'unknown' (length 584 aa).
#         Info: Generated translation for gene 'unknown' (length 203 aa).
#         Info: Generated translation for gene 'unknown' (length 141 aa).
#         Info: Generated translation for gene 'unknown' (length 231 aa).
#         Info: Generated translation for gene 'unknown' (length 253 aa).
#         Info: Generated translation for gene 'unknown' (length 238 aa).
#         Info: Generated translation for gene 'unknown' (length 298 aa).
#         Info: Generated translation for gene 'unknown' (length 92 aa).
#         Info: Generated translation for gene 'unknown' (length 130 aa).
#         Info: Generated translation for gene 'unknown' (length 1018 aa).
#         Info: Generated translation for gene 'unknown' (length 530 aa).
#         Info: Generated translation for gene 'unknown' (length 544 aa).
#         Info: Generated translation for gene 'unknown' (length 24 aa).
#     Wrote Genbank for cluster 'region_13' (type: region) to NZ_CM000951_1_region_13.gbk
#         Info: Generated translation for gene 'unknown' (length 229 aa).
#         Info: Generated translation for gene 'unknown' (length 423 aa).
#         Info: Generated translation for gene 'unknown' (length 201 aa).
#         Info: Generated translation for gene 'unknown' (length 257 aa).
#         Info: Generated translation for gene 'unknown' (length 571 aa).
#         Info: Generated translation for gene 'ccsB' (length 368 aa).
#         Info: Generated translation for gene 'unknown' (length 520 aa).
#         Info: Generated translation for gene 'unknown' (length 699 aa).
#         Info: Generated translation for gene 'uppS' (length 753 aa).
#         Info: Generated translation for gene 'unknown' (length 198 aa).
#         Info: Generated translation for gene 'unknown' (length 243 aa).
#         Info: Generated translation for gene 'unknown' (length 120 aa).
#         Info: Generated translation for gene 'unknown' (length 495 aa).
#         Info: Generated translation for gene 'unknown' (length 460 aa).
#         Info: Generated translation for gene 'unknown' (length 110 aa).
#         Info: Generated translation for gene 'unknown' (length 324 aa).
#         Info: Generated translation for gene 'unknown' (length 289 aa).
#         Info: Generated translation for gene 'unknown' (length 420 aa).
#         Info: Generated translation for gene 'unknown' (length 149 aa).
#         Info: Generated translation for gene 'unknown' (length 324 aa).
#     Wrote Genbank for cluster 'region_14' (type: region) to NZ_CM000951_1_region_14.gbk
#         Info: Generated translation for gene 'unknown' (length 197 aa).
#         Info: Generated translation for gene 'unknown' (length 153 aa).
#         Info: Generated translation for gene 'unknown' (length 130 aa).
#         Info: Generated translation for gene 'unknown' (length 735 aa).
#         Info: Generated translation for gene 'unknown' (length 206 aa).
#         Info: Generated translation for gene 'unknown' (length 312 aa).
#         Info: Generated translation for gene 'unknown' (length 57 aa).
#         Info: Generated translation for gene 'unknown' (length 172 aa).
#         Info: Generated translation for gene 'unknown' (length 193 aa).
#         Info: Generated translation for gene 'unknown' (length 633 aa).
#         Info: Generated translation for gene 'unknown' (length 46 aa).
#         Info: Generated translation for gene 'unknown' (length 357 aa).
#         Info: Generated translation for gene 'unknown' (length 406 aa).
#         Info: Generated translation for gene 'unknown' (length 1118 aa).
#         Info: Generated translation for gene 'unknown' (length 272 aa).
#         Info: Generated translation for gene 'unknown' (length 220 aa).
#         Info: Generated translation for gene 'unknown' (length 357 aa).
#         Info: Generated translation for gene 'unknown' (length 274 aa).
#         Info: Generated translation for gene 'unknown' (length 526 aa).
#     Wrote Genbank for cluster 'region_15' (type: region) to NZ_CM000951_1_region_15.gbk
#         Info: Generated translation for gene 'rsgA' (length 336 aa).
#         Info: Generated translation for gene 'aroA' (length 441 aa).
#         Info: Generated translation for gene 'unknown' (length 237 aa).
#         Info: Generated translation for gene 'unknown' (length 271 aa).
#         Info: Generated translation for gene 'unknown' (length 209 aa).
#         Info: Generated translation for gene 'sigR' (length 227 aa).
#         Info: Generated translation for gene 'rsrA' (length 103 aa).
#         Info: Generated translation for gene 'unknown' (length 441 aa).
#         Info: Generated translation for gene 'unknown' (length 418 aa).
#         Info: Generated translation for gene 'unknown' (length 327 aa).
#         Info: Generated translation for gene 'def' (length 216 aa).
#         Info: Generated translation for gene 'unknown' (length 361 aa).
#         Info: Generated translation for gene 'unknown' (length 456 aa).
#         Info: Generated translation for gene 'unknown' (length 321 aa).
#         Info: Generated translation for gene 'unknown' (length 56 aa).
#         Info: Generated translation for gene 'unknown' (length 258 aa).
#         Info: Generated translation for gene 'unknown' (length 337 aa).
#         Info: Generated translation for gene 'unknown' (length 796 aa).
#         Info: Generated translation for gene 'unknown' (length 166 aa).
#         Info: Generated translation for gene 'unknown' (length 536 aa).
#         Info: Generated translation for gene 'unknown' (length 83 aa).
#     Wrote Genbank for cluster 'region_16' (type: region) to NZ_CM000951_1_region_16.gbk
#         Info: Generated translation for gene 'unknown' (length 125 aa).
#         Info: Generated translation for gene 'miaA' (length 312 aa).
#         Info: Generated translation for gene 'unknown' (length 167 aa).
#         Info: Generated translation for gene 'dapF' (length 289 aa).
#         Info: Generated translation for gene 'unknown' (length 732 aa).
#         Info: Generated translation for gene 'unknown' (length 512 aa).
#         Info: Generated translation for gene 'hflX' (length 498 aa).
#         Info: Generated translation for gene 'unknown' (length 409 aa).
#         Info: Generated translation for gene 'unknown' (length 502 aa).
#         Info: Generated translation for gene 'unknown' (length 631 aa).
#         Info: Generated translation for gene 'unknown' (length 298 aa).
#         Info: Generated translation for gene 'unknown' (length 669 aa).
#         Info: Generated translation for gene 'lexA' (length 259 aa).
#         Info: Generated translation for gene 'nrdR' (length 192 aa).
#         Info: Generated translation for gene 'unknown' (length 966 aa).
#         Info: Generated translation for gene 'unknown' (length 235 aa).
#         Info: Generated translation for gene 'unknown' (length 174 aa).
#         Info: Generated translation for gene 'unknown' (length 201 aa).
#         Info: Generated translation for gene 'unknown' (length 219 aa).
#         Info: Generated translation for gene 'unknown' (length 301 aa).
#         Info: Generated translation for gene 'unknown' (length 515 aa).
#     Wrote Genbank for cluster 'region_17' (type: region) to NZ_CM000951_1_region_17.gbk
#         Info: Generated translation for gene 'unknown' (length 56 aa).
#         Info: Generated translation for gene 'unknown' (length 217 aa).
#         Info: Generated translation for gene 'unknown' (length 412 aa).
#         Info: Generated translation for gene 'unknown' (length 98 aa).
#         Info: Generated translation for gene 'unknown' (length 298 aa).
#         Info: Generated translation for gene 'unknown' (length 154 aa).
#         Info: Generated translation for gene 'unknown' (length 194 aa).
#         Info: Generated translation for gene 'dut' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 252 aa).
#         Info: Generated translation for gene 'unknown' (length 381 aa).
#         Info: Generated translation for gene 'unknown' (length 230 aa).
#         Info: Generated translation for gene 'unknown' (length 851 aa).
#         Info: Generated translation for gene 'unknown' (length 227 aa).
#         Info: Generated translation for gene 'unknown' (length 132 aa).
#         Info: Generated translation for gene 'unknown' (length 254 aa).
#         Info: Generated translation for gene 'unknown' (length 224 aa).
#         Info: Generated translation for gene 'unknown' (length 223 aa).
#         Info: Generated translation for gene 'unknown' (length 681 aa).
#         Info: Generated translation for gene 'unknown' (length 442 aa).
#         Info: Generated translation for gene 'unknown' (length 360 aa).
#         Info: Generated translation for gene 'unknown' (length 213 aa).
#         Info: Generated translation for gene 'unknown' (length 426 aa).
#         Info: Generated translation for gene 'unknown' (length 124 aa).
#         Info: Generated translation for gene 'unknown' (length 178 aa).
#         Info: Generated translation for gene 'unknown' (length 78 aa).
#         Info: Generated translation for gene 'unknown' (length 535 aa).
#         Info: Generated translation for gene 'unknown' (length 288 aa).
#         Info: Generated translation for gene 'unknown' (length 317 aa).
#         Info: Generated translation for gene 'unknown' (length 292 aa).
#         Info: Generated translation for gene 'unknown' (length 510 aa).
#         Info: Generated translation for gene 'unknown' (length 493 aa).
#         Info: Generated translation for gene 'unknown' (length 316 aa).
#         Info: Generated translation for gene 'fabG' (length 262 aa).
#         Info: Generated translation for gene 'unknown' (length 91 aa).
#         Info: Generated translation for gene 'unknown' (length 403 aa).
#         Info: Generated translation for gene 'unknown' (length 423 aa).
#         Info: Generated translation for gene 'unknown' (length 109 aa).
#         Info: Generated translation for gene 'unknown' (length 590 aa).
#         Info: Generated translation for gene 'unknown' (length 205 aa).
#         Info: Generated translation for gene 'unknown' (length 236 aa).
#         Info: Generated translation for gene 'unknown' (length 346 aa).
#         Info: Generated translation for gene 'unknown' (length 333 aa).
#         Info: Generated translation for gene 'unknown' (length 268 aa).
#         Info: Generated translation for gene 'unknown' (length 244 aa).
#         Info: Generated translation for gene 'unknown' (length 230 aa).
#         Info: Generated translation for gene 'unknown' (length 147 aa).
#         Info: Generated translation for gene 'unknown' (length 436 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
#         Info: Generated translation for gene 'unknown' (length 140 aa).
#         Info: Generated translation for gene 'unknown' (length 498 aa).
#         Info: Generated translation for gene 'unknown' (length 131 aa).
#         Info: Generated translation for gene 'unknown' (length 490 aa).
#         Info: Generated translation for gene 'unknown' (length 575 aa).
#         Info: Generated translation for gene 'unknown' (length 505 aa).
#         Info: Generated translation for gene 'unknown' (length 202 aa).
#         Info: Generated translation for gene 'unknown' (length 321 aa).
#         Info: Generated translation for gene 'unknown' (length 281 aa).
#         Info: Generated translation for gene 'unknown' (length 376 aa).
#         Info: Generated translation for gene 'unknown' (length 432 aa).
#         Info: Generated translation for gene 'unknown' (length 189 aa).
#         Info: Generated translation for gene 'unknown' (length 289 aa).
#         Info: Generated translation for gene 'unknown' (length 228 aa).
#         Info: Generated translation for gene 'unknown' (length 172 aa).
#         Info: Generated translation for gene 'unknown' (length 418 aa).
#         Info: Generated translation for gene 'unknown' (length 177 aa).
#         Info: Generated translation for gene 'unknown' (length 137 aa).
#         Info: Generated translation for gene 'unknown' (length 216 aa).
#         Info: Generated translation for gene 'unknown' (length 326 aa).
#         Info: Generated translation for gene 'unknown' (length 731 aa).
#     Wrote Genbank for cluster 'region_18' (type: region) to NZ_CM000951_1_region_18.gbk
#         Info: Generated translation for gene 'unknown' (length 410 aa).
#         Info: Generated translation for gene 'unknown' (length 427 aa).
#         Info: Generated translation for gene 'unknown' (length 508 aa).
#         Info: Generated translation for gene 'unknown' (length 318 aa).
#         Info: Generated translation for gene 'unknown' (length 279 aa).
#         Info: Generated translation for gene 'unknown' (length 225 aa).
#         Info: Generated translation for gene 'unknown' (length 305 aa).
#         Info: Generated translation for gene 'unknown' (length 433 aa).
#         Info: Generated translation for gene 'unknown' (length 194 aa).
#         Info: Generated translation for gene 'unknown' (length 281 aa).
#         Info: Generated translation for gene 'unknown' (length 532 aa).
#         Info: Generated translation for gene 'unknown' (length 186 aa).
#         Info: Generated translation for gene 'unknown' (length 229 aa).
#         Info: Generated translation for gene 'unknown' (length 230 aa).
#         Info: Generated translation for gene 'unknown' (length 530 aa).
#         Info: Generated translation for gene 'unknown' (length 261 aa).
#         Info: Generated translation for gene 'unknown' (length 286 aa).
#         Info: Generated translation for gene 'unknown' (length 378 aa).
#         Info: Generated translation for gene 'unknown' (length 509 aa).
#         Info: Generated translation for gene 'unknown' (length 66 aa).
#     Wrote Genbank for cluster 'region_19' (type: region) to NZ_CM000951_1_region_19.gbk
#         Info: Generated translation for gene 'hemG' (length 432 aa).
#         Info: Generated translation for gene 'unknown' (length 243 aa).
#         Info: Generated translation for gene 'unknown' (length 393 aa).
#         Info: Generated translation for gene 'unknown' (length 217 aa).
#         Info: Generated translation for gene 'unknown' (length 264 aa).
#         Info: Generated translation for gene 'unknown' (length 71 aa).
#         Info: Generated translation for gene 'unknown' (length 374 aa).
#         Info: Generated translation for gene 'unknown' (length 210 aa).
#         Info: Generated translation for gene 'unknown' (length 200 aa).
#         Info: Generated translation for gene 'unknown' (length 238 aa).
#         Info: Generated translation for gene 'unknown' (length 71 aa).
#         Info: Generated translation for gene 'unknown' (length 285 aa).
#         Info: Generated translation for gene 'unknown' (length 505 aa).
#         Info: Generated translation for gene 'unknown' (length 298 aa).
#         Info: Generated translation for gene 'unknown' (length 460 aa).
#         Info: Generated translation for gene 'unknown' (length 258 aa).
#         Info: Generated translation for gene 'unknown' (length 492 aa).
#         Info: Generated translation for gene 'unknown' (length 192 aa).
#         Info: Generated translation for gene 'unknown' (length 131 aa).
#         Info: Generated translation for gene 'zapE' (length 354 aa).
#         Info: Generated translation for gene 'unknown' (length 265 aa).
#         Info: Generated translation for gene 'unknown' (length 157 aa).
#         Info: Generated translation for gene 'murC' (length 463 aa).
#         Info: Generated translation for gene 'msrB' (length 135 aa).
#         Info: Generated translation for gene 'unknown' (length 654 aa).
#         Info: Generated translation for gene 'unknown' (length 982 aa).
#         Info: Generated translation for gene 'unknown' (length 201 aa).
#         Info: Generated translation for gene 'unknown' (length 69 aa).
#         Info: Generated translation for gene 'unknown' (length 279 aa).
#         Info: Generated translation for gene 'unknown' (length 144 aa).
#         Info: Generated translation for gene 'unknown' (length 491 aa).
#         Info: Generated translation for gene 'unknown' (length 500 aa).
#         Info: Generated translation for gene 'unknown' (length 434 aa).
#         Info: Generated translation for gene 'unknown' (length 117 aa).
#         Info: Generated translation for gene 'unknown' (length 66 aa).
#         Info: Generated translation for gene 'unknown' (length 737 aa).
#         Info: Generated translation for gene 'unknown' (length 294 aa).
#         Info: Generated translation for gene 'unknown' (length 334 aa).
#         Info: Generated translation for gene 'unknown' (length 457 aa).
#         Info: Generated translation for gene 'unknown' (length 220 aa).
#         Info: Generated translation for gene 'unknown' (length 1404 aa).
#         Info: Generated translation for gene 'unknown' (length 294 aa).
#         Info: Generated translation for gene 'unknown' (length 254 aa).
#     Wrote Genbank for cluster 'region_20' (type: region) to NZ_CM000951_1_region_20.gbk
#         Info: Generated translation for gene 'unknown' (length 220 aa).
#         Info: Generated translation for gene 'unknown' (length 220 aa).
#         Info: Generated translation for gene 'unknown' (length 308 aa).
#         Info: Generated translation for gene 'unknown' (length 216 aa).
#         Info: Generated translation for gene 'unknown' (length 383 aa).
#         Info: Generated translation for gene 'unknown' (length 250 aa).
#         Info: Generated translation for gene 'unknown' (length 1088 aa).
#         Info: Generated translation for gene 'unknown' (length 165 aa).
#         Info: Generated translation for gene 'unknown' (length 719 aa).
#         Info: Generated translation for gene 'unknown' (length 196 aa).
#         Info: Generated translation for gene 'unknown' (length 251 aa).
#         Info: Generated translation for gene 'unknown' (length 207 aa).
#         Info: Generated translation for gene 'unknown' (length 257 aa).
#         Info: Generated translation for gene 'unknown' (length 118 aa).
#         Info: Generated translation for gene 'unknown' (length 314 aa).
#         Info: Generated translation for gene 'treZ' (length 581 aa).
#         Info: Generated translation for gene 'unknown' (length 183 aa).
# ...
#         Info: Generated translation for gene 'unknown' (length 376 aa).
#         Info: Generated translation for gene 'unknown' (length 231 aa).
#         Info: Generated translation for gene 'unknown' (length 290 aa).
#         Info: Generated translation for gene 'unknown' (length 62 aa).
#         Info: Generated translation for gene 'unknown' (length 448 aa).
#         Info: Generated translation for gene 'unknown' (length 53 aa).
#         Info: Generated translation for gene 'unknown' (length 72 aa).
#         Info: Generated translation for gene 'mftG' (length 497 aa).
#         Info: Generated translation for gene 'mftF' (length 466 aa).
#         Info: Generated translation for gene 'mftC' (length 517 aa).
#         Info: Generated translation for gene 'mftA' (length 48 aa).
#         Info: Generated translation for gene 'mftR2' (length 207 aa).
#         Info: Generated translation for gene 'unknown' (length 351 aa).
#         Info: Generated translation for gene 'unknown' (length 246 aa).
#         Info: Generated translation for gene 'unknown' (length 253 aa).
#         Info: Generated translation for gene 'unknown' (length 403 aa).
#         Info: Generated translation for gene 'unknown' (length 119 aa).
#         Info: Generated translation for gene 'unknown' (length 221 aa).
#         Info: Generated translation for gene 'unknown' (length 318 aa).
#         Info: Generated translation for gene 'unknown' (length 276 aa).
#         Info: Generated translation for gene 'unknown' (length 221 aa).
#         Info: Generated translation for gene 'tuf' (length 396 aa).
#     Wrote Genbank for cluster 'region_48' (type: region) to NZ_LT985361_1_region_48.gbk
#   Processing record: NZ_LT985362.1 (Length: 107468 bp)
#   Processing record: NZ_LT985363.1 (Length: 88663 bp)
#         Info: Generated translation for gene 'unknown' (length 101 aa).
#         Info: Generated translation for gene 'unknown' (length 83 aa).
#         Info: Generated translation for gene 'unknown' (length 285 aa).
#         Info: Generated translation for gene 'unknown' (length 265 aa).
#         Info: Generated translation for gene 'unknown' (length 395 aa).
#         Info: Generated translation for gene 'unknown' (length 408 aa).
#         Info: Generated translation for gene 'unknown' (length 311 aa).
#         Info: Generated translation for gene 'unknown' (length 322 aa).
#         Info: Generated translation for gene 'unknown' (length 172 aa).
#         Info: Generated translation for gene 'unknown' (length 76 aa).
#         Info: Generated translation for gene 'unknown' (length 359 aa).
#         Info: Generated translation for gene 'unknown' (length 273 aa).
#         Info: Generated translation for gene 'unknown' (length 588 aa).
#         Info: Generated translation for gene 'unknown' (length 422 aa).
#         Info: Generated translation for gene 'unknown' (length 72 aa).
#         Info: Generated translation for gene 'unknown' (length 263 aa).
#         Info: Generated translation for gene 'unknown' (length 476 aa).
#         Info: Generated translation for gene 'unknown' (length 1108 aa).
#         Info: Generated translation for gene 'unknown' (length 292 aa).
#         Info: Generated translation for gene 'unknown' (length 435 aa).
#         Info: Generated translation for gene 'unknown' (length 279 aa).
#         Info: Generated translation for gene 'unknown' (length 79 aa).
#         Info: Generated translation for gene 'unknown' (length 729 aa).
#         Info: Generated translation for gene 'unknown' (length 465 aa).
#         Info: Generated translation for gene 'unknown' (length 309 aa).
#         Info: Generated translation for gene 'unknown' (length 314 aa).
#         Info: Generated translation for gene 'unknown' (length 282 aa).
#         Info: Generated translation for gene 'unknown' (length 133 aa).
#         Info: Generated translation for gene 'unknown' (length 372 aa).
#         Info: Generated translation for gene 'unknown' (length 127 aa).
#         Info: Generated translation for gene 'unknown' (length 418 aa).
#         Info: Generated translation for gene 'unknown' (length 265 aa).
#         Info: Generated translation for gene 'unknown' (length 59 aa).
#         Info: Generated translation for gene 'unknown' (length 412 aa).
#         Info: Generated translation for gene 'unknown' (length 316 aa).
#     Wrote Genbank for cluster 'region_1' (type: region) to NZ_LT985363_1_region_1.gbk
#         Info: Generated translation for gene 'unknown' (length 504 aa).
#         Info: Generated translation for gene 'unknown' (length 372 aa).
#         Info: Generated translation for gene 'unknown' (length 143 aa).
#         Info: Generated translation for gene 'unknown' (length 322 aa).
#         Info: Generated translation for gene 'unknown' (length 316 aa).
#         Info: Generated translation for gene 'unknown' (length 179 aa).
#         Info: Generated translation for gene 'unknown' (length 266 aa).
#         Info: Generated translation for gene 'unknown' (length 182 aa).
#         Info: Generated translation for gene 'unknown' (length 109 aa).
#         Info: Generated translation for gene 'unknown' (length 218 aa).
#         Info: Generated translation for gene 'unknown' (length 184 aa).
#         Info: Generated translation for gene 'unknown' (length 495 aa).
#         Info: Generated translation for gene 'unknown' (length 295 aa).
#         Info: Generated translation for gene 'unknown' (length 208 aa).
#         Info: Generated translation for gene 'purF' (length 491 aa).
#         Info: Generated translation for gene 'unknown' (length 208 aa).
#         Info: Generated translation for gene 'unknown' (length 804 aa).
#         Info: Generated translation for gene 'unknown' (length 2515 aa).
#     Wrote Genbank for cluster 'region_2' (type: region) to NZ_LT985363_1_region_2.gbk
#   Processing record: NZ_LT985364.1 (Length: 44107 bp)
#         Info: Generated translation for gene 'unknown' (length 1162 aa).
#         Info: Generated translation for gene 'unknown' (length 416 aa).
#         Info: Generated translation for gene 'unknown' (length 297 aa).
#         Info: Generated translation for gene 'unknown' (length 246 aa).
#         Info: Generated translation for gene 'unknown' (length 143 aa).
#         Info: Generated translation for gene 'unknown' (length 219 aa).
#         Info: Generated translation for gene 'unknown' (length 271 aa).
#         Info: Generated translation for gene 'unknown' (length 126 aa).
#         Info: Generated translation for gene 'unknown' (length 84 aa).
#         Info: Generated translation for gene 'unknown' (length 110 aa).
#         Info: Generated translation for gene 'unknown' (length 296 aa).
#         Info: Generated translation for gene 'unknown' (length 70 aa).
#         Info: Generated translation for gene 'unknown' (length 105 aa).
#         Info: Generated translation for gene 'unknown' (length 317 aa).
#         Info: Generated translation for gene 'unknown' (length 404 aa).
#         Info: Generated translation for gene 'unknown' (length 182 aa).
#         Info: Generated translation for gene 'unknown' (length 155 aa).
#         Info: Generated translation for gene 'unknown' (length 385 aa).
#         Info: Generated translation for gene 'unknown' (length 271 aa).
#         Info: Generated translation for gene 'unknown' (length 186 aa).
#         Info: Generated translation for gene 'unknown' (length 552 aa).
#         Info: Generated translation for gene 'unknown' (length 403 aa).
#     Wrote Genbank for cluster 'region_1' (type: region) to NZ_LT985364_1_region_1.gbk
#   Processing record: NZ_LT985365.1 (Length: 22554 bp)
#   Processing record: NZ_LT985366.1 (Length: 21426 bp)
#   Processing record: NZ_LT985367.1 (Length: 13663 bp)
#   Processing record: NZ_LT985368.1 (Length: 7306 bp)
#   Processing record: NZ_LT985369.1 (Length: 6685 bp)
#   Processing record: NZ_LT985370.1 (Length: 3264 bp)
#   Processing record: NZ_LT985371.1 (Length: 2988 bp)
#   Processing record: NZ_LT985372.1 (Length: 2859 bp)
#   Processing record: NZ_LT985373.1 (Length: 2829 bp)
#   Processing record: NZ_LT985374.1 (Length: 2790 bp)
#   Processing record: NZ_LT985375.1 (Length: 2430 bp)
#   Processing record: NZ_LT985376.1 (Length: 2194 bp)
#   Processing record: NZ_LT985377.1 (Length: 2065 bp)
#   Processing record: NZ_LT985378.1 (Length: 1710 bp)
#   Processing record: NZ_LT985379.1 (Length: 1506 bp)
#   Processing record: NZ_LT985380.1 (Length: 1375 bp)
#   Processing record: NZ_LT985381.1 (Length: 1186 bp)
#   Processing record: NZ_LT985382.1 (Length: 1023 bp)
#   Processing record: NZ_LT985383.1 (Length: 897 bp)
#   Processing record: NZ_LT985384.1 (Length: 894 bp)
#   Processing record: NZ_LT985385.1 (Length: 879 bp)
#   Finished processing GCF_900269665.1.gbk. Identified 51 features matching specified types. Successfully wrote 51 files after filtering by length.
# --------------------------------------------------
#
# --- Processing file: X65195.gbk ---
#   Outputting to: split_gbk_regions_output
#   Looking for feature types: region
#   Minimum region length: 1000 bp
#   Processing record: X65195.2 (Length: 37823 bp)
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [116:530](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [669:1557](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [2171:2381](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'phsB' (length 1189 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [2377:5947](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [5939:7601](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'phsC' (length 1086 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [7673:10934](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'pmi' (length 889 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [11044:13714](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'adhP' (length 395 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [13770:14958](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [14981:16280](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'pgdP' (length 336 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [16290:17301](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'ppm' (length 313 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [17345:18287](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'ppd' (length 397 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [18283:19477](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [19473:20028](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'pgmP' (length 419 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [20083:21343](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'cpps' (length 398 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [21339:22536](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'cppm' (length 296 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [22610:23501](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'aldP' (length 466 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [23551:24952](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'pmet' (length 549 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [25007:26657](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'pms' (length 440 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [26653:27976](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'phsA' (length 622 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [28009:29878](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'pat' (length 183 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [29929:30481](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'dea' (length 299 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [30492:31392](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'the1' (length 252 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [31388:32147](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'the2' (length 260 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [32143:32926](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'trs' (length 412 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [32922:34161](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Info: Generated translation for gene 'prpA' (length 301 aa).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [34482:35388](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [35361:36612](-)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [36629:37208](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#         Warning: Skipping CDS feature 'unknown' (in original record X65195.2, location: [37253:>37823](+)) due to missing/malformed essential qualifiers: locus_tag (missing or empty).
#     Wrote Genbank for cluster 'region_1' (type: region) to X65195_2_region_1.gbk
#   Finished processing X65195.gbk. Identified 1 features matching specified types. Successfully wrote 1 files after filtering by length.
# --------------------------------------------------
#
# All specified GenBank files processed. Output can be found in 'split_gbk_regions_output'.
